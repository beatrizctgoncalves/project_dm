# %% [markdown]
# # Data Mining Final Project 2021 - 2022
# ## Authors: Beatriz Gonçalves (m20210695), Diogo Hipólito (m20210633) and Diogo Pereira (m20210657)

# %% [markdown]
# # 1) Introduction

# %% [markdown]
# The client, a Marketing Department from an an insurance company, wishes to better understand the scope of its clients, in order to better serve them and increase their ROI (Return On Investment). The group was given an ABT (Analytic Based Table), consisting of 10.290 customers and given the task of analyzing the table for evident groups of clusters, extracting the behaviour of said clusters and provide insights on how to better serve them.
#
# The project is contained within a Github repository which can be accessed through the following link: https://github.com/beatrizctgoncalves/project_dm. This repository provides a Jupyter Notebook with all the relevant analysis and a report that summarizes the work done. Note that these two documents should be used together as they complement each other.

# %% [markdown]
# ## 1.1: Setup Environment

# %% [markdown]
# ...

# %% [markdown]
# ## 1.2: Importing Packages

# %%
# Required imports for the project
#pip install sas7bdat

from sas7bdat import SAS7BDAT
import numpy as np
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) Importing and Assessing Data

# %%
df_insurance = pd.read_sas('a2z_insurance.sas7bdat')
con = sqlite3.connect('file.db')

# Build Analytical Base Table (ABT)
df_insurance.to_sql(name='file', con=con, if_exists = 'replace', index=False)

# %%
df_insurance.head()
# Out:
#    CustID  FirstPolYear  BirthYear             EducDeg  MonthSal  GeoLivArea  \
# 0     1.0        1985.0     1982.0  b'2 - High School'    2177.0         1.0
# 1     2.0        1981.0     1995.0  b'2 - High School'     677.0         4.0
# 2     3.0        1991.0     1970.0        b'1 - Basic'    2277.0         3.0
# 3     4.0        1990.0     1981.0      b'3 - BSc/MSc'    1099.0         4.0
# 4     5.0        1986.0     1973.0      b'3 - BSc/MSc'    1763.0         4.0
#
#    Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# 0       1.0      380.97        0.39     375.85          79.45      146.36
# 1       1.0     -131.13        1.12      77.46         416.20      116.69
# 2       0.0      504.67        0.28     206.15         224.50      124.58
# 3       1.0      -16.99        0.99     182.48          43.35      311.17
# 4       1.0       35.23        0.90     338.62          47.80      182.59
#
#    PremLife  PremWork
# 0     47.01     16.89
# 1    194.48    106.13
# 2     86.35     99.02
# 3     35.34     28.34
# 4     18.78     41.45

# %%
# Dimension of the dataset
df_insurance.shape
# Out:
# (10296, 14)

# %%
# Data types of the variables
df_insurance.dtypes
# Out:
# CustID           float64
# FirstPolYear     float64
# BirthYear        float64
# EducDeg           object
# MonthSal         float64
# GeoLivArea       float64
# Children         float64
# CustMonVal       float64
# ClaimsRate       float64
# PremMotor        float64
# PremHousehold    float64
# PremHealth       float64
# PremLife         float64
# PremWork         float64
# dtype: object

# %%
# Correcting some data types
# "first_policy":int, "birthday":int, "salary":int, can't be converted due to NAs
df_insurance['CustID'] = (df_insurance['CustID'].astype(float)).astype(int)

# %%
# Get summary statistics from df
df_insurance.iloc[:,1:].describe(include='all')
# Out:
#         FirstPolYear     BirthYear         EducDeg      MonthSal  \
# count   10266.000000  10279.000000           10279  10260.000000
# unique           NaN           NaN               4           NaN
# top              NaN           NaN  b'3 - BSc/MSc'           NaN
# freq             NaN           NaN            4799           NaN
# mean     1991.062634   1968.007783             NaN   2506.667057
# std       511.267913     19.709476             NaN   1157.449634
# min      1974.000000   1028.000000             NaN    333.000000
# 25%      1980.000000   1953.000000             NaN   1706.000000
# 50%      1986.000000   1968.000000             NaN   2501.500000
# 75%      1992.000000   1983.000000             NaN   3290.250000
# max     53784.000000   2001.000000             NaN  55215.000000
#
#           GeoLivArea      Children     CustMonVal    ClaimsRate     PremMotor  \
# count   10295.000000  10275.000000   10296.000000  10296.000000  10262.000000
# unique           NaN           NaN            NaN           NaN           NaN
# top              NaN           NaN            NaN           NaN           NaN
# freq             NaN           NaN            NaN           NaN           NaN
# mean        2.709859      0.706764     177.892605      0.742772    300.470252
# std         1.266291      0.455268    1945.811505      2.916964    211.914997
# min         1.000000      0.000000 -165680.420000      0.000000     -4.110000
# 25%         1.000000      0.000000      -9.440000      0.390000    190.590000
# 50%         3.000000      1.000000     186.870000      0.720000    298.610000
# 75%         4.000000      1.000000     399.777500      0.980000    408.300000
# max         4.000000      1.000000   11875.890000    256.200000  11604.420000
#
#         PremHousehold    PremHealth      PremLife      PremWork
# count    10296.000000  10253.000000  10192.000000  10210.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean       210.431192    171.580833     41.855782     41.277514
# std        352.595984    296.405976     47.480632     51.513572
# min        -75.000000     -2.110000     -7.000000    -12.000000
# 25%         49.450000    111.800000      9.890000     10.670000
# 50%        132.800000    162.810000     25.560000     25.670000
# 75%        290.050000    219.820000     57.790000     56.790000
# max      25048.800000  28272.000000    398.300000   1988.700000

# %%
# More info about df
df_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         10296 non-null  int64
#  1   FirstPolYear   10266 non-null  float64
#  2   BirthYear      10279 non-null  float64
#  3   EducDeg        10279 non-null  object
#  4   MonthSal       10260 non-null  float64
#  5   GeoLivArea     10295 non-null  float64
#  6   Children       10275 non-null  float64
#  7   CustMonVal     10296 non-null  float64
#  8   ClaimsRate     10296 non-null  float64
#  9   PremMotor      10262 non-null  float64
#  10  PremHousehold  10296 non-null  float64
#  11  PremHealth     10253 non-null  float64
#  12  PremLife       10192 non-null  float64
#  13  PremWork       10210 non-null  float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
# Check duplicates
any(df_insurance.duplicated())
# Out:
# False

# %%
# Number of missing values in each feature
df_insurance.isna().sum()
# Out:
# CustID             0
# FirstPolYear      30
# BirthYear         17
# EducDeg           17
# MonthSal          36
# GeoLivArea         1
# Children          21
# CustMonVal         0
# ClaimsRate         0
# PremMotor         34
# PremHousehold      0
# PremHealth        43
# PremLife         104
# PremWork          86
# dtype: int64

# %%
# Frequencies of number of missing values across rows
df_insurance.isna().apply(lambda x:sum(x), axis=1).value_counts().sort_index()
# Out:
# 0    9987
# 1     256
# 2      38
# 3       3
# 4      12
# dtype: int64

# %%
# Define metric and non-metric datasets
metric_df = df_insurance.loc[:, (df_insurance.columns=='CustID') | (np.array(df_insurance.dtypes=="float64"))]
non_metric_df = df_insurance.loc[:, (df_insurance.columns=='CustID') | (np.array(df_insurance.dtypes=="object"))]

# %%
sns.set()

# Setting pairgrid
g = sns.PairGrid(metric_df.drop('CustID', 1).dropna())

# Populating pairgrid
mdg = g.map_diag(plt.hist, edgecolor="w")
mog = g.map_offdiag(plt.scatter, edgecolor="w", s=40)

# Layout
plt.subplots_adjust(top=0.95)
plt.suptitle("Pairwise relationship of metric variables", fontsize=20)

plt.show()

# %%
### Acho que isto está fixe!
